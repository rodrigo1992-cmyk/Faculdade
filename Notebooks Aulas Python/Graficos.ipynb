# %%
import matplotlib.pyplot as plt # biblioteca para gerar os graficos
import numpy as np # biblioteca numerica.
import pandas as pd # bilioteca de leitura de dados tabulares(dataframes)
import seaborn as sns

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![picture 0](../images/89dac90f3f9ce28e9cf35bd6f37eb348e2eb7d70c649ec7b0b07a49c2eedb06f.png)

# %% [markdown]
# GRAF BARRAS MATPLOT

# %%
#MATPLOT
categories = ['Cat A','Cat B','Cat C','Cat D']
values = [25,40,30,50]

plt.bar(categories,values)
plt.xlabel('Categorias')
plt.ylabel('valores')
plt.title('Exemplo')
plt.show()

# %% [markdown]
# GRAF BARRAS PANDAS

# %%
#PANDAS
categories = ['Cat A','Cat B','Cat C','Cat D']
values = [25,40,30,50]

dic = {'categories':categories, 'values':values}
df = pd.DataFrame(dic)

df.plot(kind = 'bar', x= 'categories')
plt.xticks(rotation = 0)

plt.xlabel('Categorias')
plt.ylabel('valores')
plt.title('Exemplo')
plt.show()

del dic
del df

# %% [markdown]
# GRAF BARRAS SEABORN

# %%
categories = ['Cat A','Cat B','Cat C','Cat D']
values = [25,40,30,50]
dic = {'categories':categories, 'values':values}

sns.barplot(x='categories', y='values', data = dic) #Posso usar dicionário ou DataFrame
plt.show()

del dic

# %% [markdown]
# GRAF LINHAS MATPLOT

# %%
x = [1,2,3,4,5,6]
y = [10,12,8,9,11,12]

plt.plot(x,y)
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.title('Gráfico de Linha')
plt.ylim(bottom=0)
plt.show()

# %% [markdown]
# GRAF LINHAS PANDAS

# %%
x = [1,2,3,4,5,6]
y = [10,12,8,9,11,12]

dic = {'categories':x, 'values':y}
df = pd.DataFrame(dic)

df.plot(kind= 'line', x='categories', y='values')

plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.title('Gráfico de Linha')
plt.ylim(bottom=0)
plt.show()

del dic
del df

# %% [markdown]
# GRAF LINHAS SEABORN

# %%
x = [1,2,3,4,5,6]
y = [10,12,8,9,11,12]

dic = {'categories':x, 'values':y}

sns.lineplot(data = dic, x='categories', y='values')

plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.title('Gráfico de Linha')
plt.ylim(bottom=0)
plt.show()

del dic

# %% [markdown]
# GRAF BOXPLOT MATPLOT

# %%
y = [10,12,8,9,11,12]

plt.boxplot(x = y)
plt.show()

# %% [markdown]
# GRAF BOXPLOT PANDAS

# %%
y = [10,12,8,9,11,12]
x = [1,1,1,2,2,2]

dic = {'values':y}
df = pd.DataFrame(dic)

df.plot(kind='box', y='values') 
#Criar um boxplot para cada categoria

plt.show()

del dic
del df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\RodrigoPintoMesquita\.vscode\Meus Notebooks\Python\notebooks\Graficos.ipynb Cell 19 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/RodrigoPintoMesquita/.vscode/Meus%20Notebooks/Python/notebooks/Graficos.ipynb#X25sZmlsZQ%3D%3D?line=1'>2</a> x = [1,1,1,2,2,2]
#       <a href='vscode-notebook-cell:/c%3A/Users/RodrigoPintoMesquita/.vscode/Meus%20Notebooks/Python/notebooks/Graficos.ipynb#X25sZmlsZQ%3D%3D?line=3'>4</a> dic = {'values':y}
# ----> <a href='vscode-notebook-cell:/c%3A/Users/RodrigoPintoMesquita/.vscode/Meus%20Notebooks/Python/notebooks/Graficos.ipynb#X25sZmlsZQ%3D%3D?line=4'>5</a> df = pd.DataFrame(dic)
#       <a href='vscode-notebook-cell:/c%3A/Users/RodrigoPintoMesquita/.vscode/Meus%20Notebooks/Python/notebooks/Graficos.ipynb#X25sZmlsZQ%3D%3D?line=6'>7</a> df.plot(kind='box', y='values')
#       <a href='vscode-notebook-cell:/c%3A/Users/RodrigoPintoMesquita/.vscode/Meus%20Notebooks/Python/notebooks/Graficos.ipynb#X25sZmlsZQ%3D%3D?line=7'>8</a> #Criar um boxplot para cada categoria
#
# NameError: name 'pd' is not defined

# %% [markdown]
# GRAF BOXPLOT SEABORN

# %%
y = [10,12,8,9,11,12]

dic = {'values':y}

sns.boxplot(data = dic, y='values')
plt.show()

del dic

# %% [markdown]
# GRAF SCATTER MATPLOT

# %%
mes = [1,1,1,1,2,2,2,3,4,4,5,5,5,5,5]
valor = [10,15,14,13,20,23,10,30,25,20,34,33,10,12,14]

plt.scatter(x = mes, y=valor)

# %% [markdown]
# GRAF SCATTER PANDAS

# %%
mes = [1,1,1,1,2,2,2,3,4,4,5,5,5,5,5]
valor = [10,15,14,13,20,23,10,30,25,20,34,33,10,12,14]

dic = {'categories': mes, 'values': valor}
df = pd.DataFrame(dic)
df.plot(kind = 'scatter', x = 'categories', y='values')


del dic
del df

# %% [markdown]
# GRAF SCATTER SEABORN

# %%
mes = [1,1,1,1,2,2,2,3,4,4,5,5,5,5,5]
valor = [10,15,14,13,20,23,10,30,25,20,34,33,10,12,14]

dic = {'categories': mes, 'values': valor}
sns.scatterplot(data = dic, x = 'categories', y='values')

del dic

# %% [markdown]
# GRAF PIZZA MATPLOT

# %%
mes = ['jan','fev','mar','abr','mai']
valor = [10,20,30,25,34]

plt.pie(x = valor, labels = mes, autopct = '%1.1f%%',startangle = 90)
plt.show()

# %% [markdown]
# GRAF PIZZA PANDAS

# %%
mes = ['jan','fev','mar','abr','mai']
valor = [10,20,30,25,34]

df = pd.DataFrame({'categories': mes, 'values': valor}).sort_values('values',ascending=True)

df.plot(kind = 'pie', y = 'values', labels = df['categories'], autopct = '%1.1f%%',startangle = 90)
plt.legend(bbox_to_anchor=(1.02,1), loc='upper left', borderaxespad=0) #Plotar legenda fora da área do gráfico
plt.show()

del df

# %% [markdown]
# GRAF PIZZA SEABORN

# %%
#Não há gráfico de pizza no Seaborn

# %% [markdown]
# HISTOGRAMA MATPLOT

# %%
dados = np.random.normal(0,1,1000)

plt.hist(dados, bins=40) #
plt.xlabel('valores')
plt.ylabel('frequencia')
plt.title('Histograma')
plt.show()

# %% [markdown]
# HISTOGRAMA PANDAS

# %%
df = pd.DataFrame({'dados': np.random.normal(0,1,1000)})

df.plot(kind='hist', bins=40)
plt.xlabel('valores')
plt.ylabel('frequencia')
plt.title('Histograma')
plt.show()

del df

# %% [markdown]
# HISTOGRAMA SEABORN

# %%
df = pd.DataFrame({'dados': np.random.normal(0,1,1000)})

sns.histplot(data = df, x='dados')

del df

# %% [markdown]
# GRAF RADAR MATPLOT

# %%
categoria = ['Fatia 1','Fatia 2','Fatia 3','Fatia 4',]
valor = [10,20,5,15]

plt.polar() #Plota o grid do radar
plt.plot(categoria + [categoria[0]], valor + [valor[0]], marker = 'o') #Plota a linha
plt.fill(categoria + [categoria[0]], valor + [valor[0]], alpha = 0.3) #Preenche a linha
plt.title('Gráfico de Radar')
plt.show()

# %% [markdown]
# MAPA DE CALOR MATPLOT

# %%
data = np.random.rand(10,10) #Gera uma matriz aleatória de 10x10
plt.imshow(data,cmap='cool', interpolation ='nearest')
plt.colorbar()
plt.title('Mapa de Calor')
plt.show()

# %% [markdown]
# MAPA DE CALOR SEABORN

# %%
dados = (np.random.rand(10,10))

sns.heatmap(data=dados)
plt.title('Mapa de Calor')
plt.show()

# %% [markdown]
# MAPA DE CALOR SEABORN (TIPO 2)

# %%
sns.set()
flights = sns.load_dataset("flights")
df = flights.pivot_table(index = "month", columns = "year", values = "passengers") # é feito um unpivot dos dados para que os eixos X e Y já correspondam ao esperado no heatmap

ax = sns.heatmap(data = df)
plt.show()

# %% [markdown]
# GRÁFICO DE ÁREA MATPLOT

# %%
x = [1,2,3,4,5,6]
y = [10,12,8,9,11,12]

plt.fill_between(x,y)
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.title('Gráfico de Área')
plt.show()

# %% [markdown]
# GRAF MULTLINHA MATPLOT

# %%
banana = [2,4,3,4,5,6]
uva = [10,12,8,9,11,12]
caqui = [8,7,6,9,10,11]
meses = ['jan','fev','mar','abr','mai','jun']

plt.plot(meses,banana, label = 'banana')
plt.plot(meses,uva, label = 'uva')
plt.plot(meses,caqui, label = 'caqui')

plt.xlabel('meses')
plt.ylabel('quantidade')
plt.title('Gráfico de Multi Linha')
plt.ylim(bottom=0)
plt.legend()

for i, j in zip(meses, banana):
    plt.text(i, j, str(j))

for i, j in zip(meses, uva):
    plt.text(i, j, str(j))

for i, j in zip(meses, caqui):
    plt.text(i, j, str(j))

plt.show()

# %%
df_gold.plot(kind = 'barh', x='Team',legend=False, title = 'Top 10 Países Ganhadores de Ouro', xlabel='Quantidade de Medalhas', ylabel = 'País')
plt.grid(axis='x')

for i,j in zip(df_gold['count'],df_gold['Team']):
    plt.text(i, j, str(j))

plt.show()
# Out:
# ---------------------------------------------------------------------------
#
# ValueError                                Traceback (most recent call last)
#
# File c:\Users\RodrigoPintoMesquita\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axis.py:1732, in Axis.convert_units(self, x)
#
#    1731 try:
#
# -> 1732     ret = self.converter.convert(x, self.units, self)
#
#    1733 except Exception as e:
#
#
#
# File c:\Users\RodrigoPintoMesquita\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\category.py:49, in StrCategoryConverter.convert(value, unit, axis)
#
#      48 if unit is None:
#
# ---> 49     raise ValueError(
#
#      50         'Missing category information for StrCategoryConverter; '
#
#      51         'this might be caused by unintendedly mixing categorical and '
#
#      52         'numeric data')
#
#      53 StrCategoryConverter._validate_unit(unit)
#
#
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
#
#
# The above exception was the direct cause of the following exception:
#
#
#
# ConversionError                           Traceback (most recent call last)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\formatters.py:340, in BaseFormatter.__call__(self, obj)
#
#     338     pass
#
#     339 else:
#
# --> 340     return printer(obj)
#
#     341 # Finally look for special method names
#
#     342 method = get_real_method(obj, self.print_method)
#
#
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#
#     149     from matplotlib.backend_bases import FigureCanvasBase
#
#     150     FigureCanvasBase(fig)
#
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#
#     153 data = bytes_io.getvalue()
#
#     154 if fmt == 'svg':
#
#
#
# File c:\Users\RodrigoPintoMesquita\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\backend_bases.py:2342, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#
#    2336     renderer = _get_renderer(
#
#    2337         self.figure,
#
#    2338         functools.partial(
#
#    2339             print_method, orientation=orientation)
#
#    2340     )
#
#    2341     with getattr(renderer, "_draw_disabled", nullcontext)():
#
# -> 2342         self.figure.draw(renderer)
#
#    2344 if bbox_inches:
#
#    2345     if bbox_inches == "tight":
#
#
#
# File c:\Users\RodrigoPintoMesquita\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#
#      93 @wraps(draw)
#
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
#
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#
#      96     if renderer._rasterizing:
#
#      97         renderer.stop_rasterizing()
#
#
#
# File c:\Users\RodrigoPintoMesquita\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#
#      69     if artist.get_agg_filter() is not None:
#
#      70         renderer.start_filter()
#
# ---> 72     return draw(artist, renderer)
#
#      73 finally:
#
#      74     if artist.get_agg_filter() is not None:
#
#
#
# File c:\Users\RodrigoPintoMesquita\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\figure.py:3175, in Figure.draw(self, renderer)
#
#    3172         # ValueError can occur when resizing a window.
#
#    3174 self.patch.draw(renderer)
#
# -> 3175 mimage._draw_list_compositing_images(
#
#    3176     renderer, self, artists, self.suppressComposite)
#
#    3178 for sfig in self.subfigs:
#
#    3179     sfig.draw(renderer)
#
#
#
# File c:\Users\RodrigoPintoMesquita\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#
#     129 if not_composite or not has_images:
#
#     130     for a in artists:
#
# --> 131         a.draw(renderer)
#
#     132 else:
#
#     133     # Composite any adjacent images together
#
#     134     image_group = []
#
#
#
# File c:\Users\RodrigoPintoMesquita\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#
#      69     if artist.get_agg_filter() is not None:
#
#      70         renderer.start_filter()
#
# ---> 72     return draw(artist, renderer)
#
#      73 finally:
#
#      74     if artist.get_agg_filter() is not None:
#
#
#
# File c:\Users\RodrigoPintoMesquita\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_base.py:3064, in _AxesBase.draw(self, renderer)
#
#    3061 if artists_rasterized:
#
#    3062     _draw_rasterized(self.figure, artists_rasterized, renderer)
#
# -> 3064 mimage._draw_list_compositing_images(
#
#    3065     renderer, self, artists, self.figure.suppressComposite)
#
#    3067 renderer.close_group('axes')
#
#    3068 self.stale = False
#
#
#
# File c:\Users\RodrigoPintoMesquita\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#
#     129 if not_composite or not has_images:
#
#     130     for a in artists:
#
# --> 131         a.draw(renderer)
#
#     132 else:
#
#     133     # Composite any adjacent images together
#
#     134     image_group = []
#
#
#
# File c:\Users\RodrigoPintoMesquita\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#
#      69     if artist.get_agg_filter() is not None:
#
#      70         renderer.start_filter()
#
# ---> 72     return draw(artist, renderer)
#
#      73 finally:
#
#      74     if artist.get_agg_filter() is not None:
#
#
#
# File c:\Users\RodrigoPintoMesquita\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\text.py:758, in Text.draw(self, renderer)
#
#     755 # don't use self.get_position here, which refers to text
#
#     756 # position in Text:
#
#     757 posx = float(self.convert_xunits(self._x))
#
# --> 758 posy = float(self.convert_yunits(self._y))
#
#     759 posx, posy = trans.transform((posx, posy))
#
#     760 if not np.isfinite(posx) or not np.isfinite(posy):
#
#
#
# File c:\Users\RodrigoPintoMesquita\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:293, in Artist.convert_yunits(self, y)
#
#     291 if ax is None or ax.yaxis is None:
#
#     292     return y
#
# --> 293 return ax.yaxis.convert_units(y)
#
#
#
# File c:\Users\RodrigoPintoMesquita\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axis.py:1734, in Axis.convert_units(self, x)
#
#    1732     ret = self.converter.convert(x, self.units, self)
#
#    1733 except Exception as e:
#
# -> 1734     raise munits.ConversionError('Failed to convert value(s) to axis '
#
#    1735                                  f'units: {x!r}') from e
#
#    1736 return ret
#
#
#
# ConversionError: Failed to convert value(s) to axis units: 'Russia'

# %% [markdown]
# GRAF MULTLINHA SEABORN

# %%
df = pd.DataFrame({'meses': ['jan','fev','mar','abr','mai','jun'],
                    'banana': [2,4,3,4,5,6],
                    'uva': [10,12,8,9,11,12],
                    'caqui': [8,7,6,9,10,11]})

sns.lineplot(data=df[['banana', 'uva', 'caqui']], palette=['red', 'blue', 'purple'])
plt.show()

del df

# %% [markdown]
# PAIRPLOT SEABORN

# %%
sns.set(style="ticks", color_codes=True)
iris = sns.load_dataset("iris")
sns.pairplot(iris)

plt.show()
# Out:
# c:\Users\RodrigoPintoMesquita\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# GRAF BARRA DE ERROS MATPLOT (errorbar)

# %%
x = np.array([1,2,3,4,5,6])
y = np.array([10,12,8,9,11,12])
matriz_erro = np.array([0.4, 0.7, 0.3, 0.5, 0.2, 0.6]) #Valores de margem de erro para cada ponto do gráfico

plt.errorbar(x, y, yerr = matriz_erro, fmt='o', color='blue', ecolor ='red', capsize=5, label='Margem de Erro') #Se quiser adicionar a margem de erro no eixo Y basta utilizar o 'xerr' no lugar do 'yerr'

#Eu posso combinar o error bar com quase qualquer gráfico, basta adicionar a instrução do gráfico desejado em seguida, como o abaixo que deixei comentado
#plt.plot(x,y)
plt.legend()
plt.show()

# %% [markdown]
# GRAF GANT MATPLOT

# %%
meu_dic = {'Atividades': ['Atividade1','Atividade2','Atividade3'],
       'Dt inicio': ['2023-01-01','2023-01-10','2023-01-20'],
       'Dt fim': ['2023-01-10','2023-01-25','2023-01-30']}

meu_df = pd.DataFrame(meu_dic) #Converter o dicionário para um Dataframe do Pandas

meu_df['Dt inicio'] = pd.to_datetime(meu_df['Dt inicio']) #Converter os campos de data
meu_df['Dt fim'] = pd.to_datetime(meu_df['Dt fim']) #Converter os campos de data

lista_datas = pd.date_range(min(meu_df['Dt inicio']),max(meu_df['Dt fim']))
lista_ticks = list(range(0,len(lista_datas)))

#Começar o Plot do Gantt
plt.barh(meu_df['Atividades'], width=(meu_df['Dt fim'] - meu_df['Dt inicio']).dt.days, left=meu_df['Dt inicio'])
plt.xticks(lista_datas,lista_datas,rotation = 45)
plt.xlabel('Data', rotation = 0)
plt.ylabel('Tarefas')
plt.title('Gráfico de Gantt')
plt.show()

# %% [markdown]
# SUBPLOTS MATPLOT

# %%
#Segue abaixo formato da instrução com principais parâmetros
#fig,axes = plt.subplots(nrows, ncols, figsize = (width, height))

#Criando um conjunto de dados qualquer para serem plotados
x = np.linspace(0,10,100)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.exp(-x/5) * np.sin(x)

#Passando a configuração do subplot, que é basicamente o grid
fig,axes = plt.subplots(1,3, figsize =(16,4), sharey = True) #O parâmetro Share Y faz com que aparece o eixo Y somente no primeiro gráfico.

#todos os gráficos que vierem após a instrução do subplot serão entendidos como parte do grid
axes[0].plot(x, y1, label="sin(x)", color="blue")
axes[0].set_title('sin(x)')
axes[0].legend()

axes[1].plot(x, y2, label='cos(x)', color='red')
axes[1].set_title('cos(x)')
axes[1].legend()

axes[2].plot(x, y3, label='exp(-x/5) * np.sin(x)', color='green')
axes[2].set_title('exp(-x/5) * np.sin(x)')
axes[2].legend()


plt.tight_layout() #Só serve para que não haja espaçamento entre os gráficos
plt.show()

# %%
#Se quiser que o Grid possua linhas e colunas os gráficos tem de ser identificados por uma tupla de[linha,coluna]

fig,axes = plt.subplots(2,2, figsize =(16,4), sharey = True) #O parâmetro Share Y faz com que aparece o eixo Y somente no primeiro gráfico.

#todos os gráficos que vierem após a instrução do subplot serão entendidos como parte do grid
axes[0,0].plot(x, y1, label="sin(x)", color="blue")
axes[0,0].set_title('graf_1')
axes[0,0].legend()

axes[0,1].plot(x, y2, label='cos(x)', color='red')
axes[0,1].set_title('graf_2')
axes[0,1].legend()

axes[1,0].plot(x, y3, label='exp(-x/5) * np.sin(x)', color='green')
axes[1,0].set_title('graf_3')
axes[1,0].legend()

axes[1,1].plot(x, y2, label='cos(x)', color='pink')
axes[1,1].set_title('graf_4')
axes[1,1].legend()

plt.tight_layout() #Só serve para que não haja espaçamento entre os gráficos
plt.show()

# %% [markdown]
# PLOTAR LEGENDA FORA DA ÁREA DO GRÁFICO

# %%
mes = ['jan','fev','mar','abr','mai']
valor = [10,20,30,25,34]

df = pd.DataFrame({'categories': mes, 'values': valor}).sort_values('values',ascending=True)

df.plot(kind = 'pie', y = 'values', labels = df['categories'], autopct = '%1.1f%%',startangle = 90)
plt.legend(bbox_to_anchor=(1.02,1), loc='upper left', borderaxespad=0) #Plotar legenda fora da área do gráfico
plt.show()

# %% [markdown]
# TODOS OS TIPOS DE MARKERS DO MATPLOT

# %%
x = np.arange(5)
y = x
plt.plot(x, y, '.')
plt.plot(x, y+0.5, ',')
plt.plot(x, y+1, 'o')
plt.plot(x, y+2, '<')
plt.plot(x, y+3, '>')
plt.plot(x, y+4, 'v')
plt.plot(x, y+5, '^')
plt.plot(x, y+6, '1')
plt.plot(x, y+7, '2')
plt.plot(x, y+8, '3')
plt.plot(x, y+9, '4')
plt.plot(x, y+10, 's')
plt.plot(x, y+11, 'p')
plt.plot(x, y+12, '*')
plt.plot(x, y+13, 'h')
plt.plot(x, y+14, 'H')
plt.plot(x, y+15, '+')
plt.plot(x, y+16, 'D')
plt.plot(x, y+17, 'd')
plt.plot(x, y+18, '|')
plt.plot(x, y+19, '_')
plt.show()

# %%
#nomeclatura cor tipo de marcador, estilo delinha
plt.plot(x, y, 'mo--')
plt.plot(x, y+1 , 'g^-.')
plt.show()

# %%
plt.plot(x, y, 
    color='orange', 
    linestyle='--', 
    linewidth=5,
    marker='^', 
    markerfacecolor='b', 
    markeredgecolor='r',
    markeredgewidth=1.5, 
    markersize=10)
plt.show()
