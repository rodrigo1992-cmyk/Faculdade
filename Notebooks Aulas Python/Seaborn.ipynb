# %%
import pandas as pd
import seaborn as sns

# %%
meu_dataset = [{'idade':31,
               'cor':'branco',
               'nome':'rodrigo',
               'filiação':{'pai':'sergio', 'mae':'marcia'},
               'natural':'rio de janeiro'},
               {'idade':32,
               'cor':'moreno',
               'nome':'jonatas',
               'filiação':{'pai':'n/a', 'mae':'n/a'},
               'natural':'natal'},
               {'idade':32,
               'cor':'branco',
               'nome':'allan',
               'filiação':{'pai':'n/a', 'mae':'n/a'},
               'natural':'duque de caxias'},
               ]

meu_dataset = pd.DataFrame(meu_dataset)

meu_dataset
# Out:
#    idade     cor     nome                            filiação          natural
# 0     31  branco  rodrigo  {'pai': 'sergio', 'mae': 'marcia'}   rio de janeiro
# 1     32  moreno  jonatas        {'pai': 'n/a', 'mae': 'n/a'}            natal
# 2     32  branco    allan        {'pai': 'n/a', 'mae': 'n/a'}  duque de caxias

# %%
import kaggle as kag
from kaggle.api.kaggle_api_extended import KaggleApi

api = KaggleApi()
api.authenticate()

# %%
api.datasets_list(search ="titanic")
# Out:
# [{'subtitleNullable': 'Suited for binary logistic regression',
#   'creatorNameNullable': 'Khashayar Baghizadeh Hosseini',
#   'creatorUrlNullable': 'heptapod',
#   'totalBytesNullable': 11090,
#   'urlNullable': 'https://www.kaggle.com/datasets/heptapod/titanic',
#   'licenseNameNullable': 'Database: Open Database, Contents: Database Contents',
#   'descriptionNullable': None,
#   'ownerNameNullable': 'Khashayar Baghizadeh Hosseini',
#   'ownerRefNullable': 'heptapod',
#   'titleNullable': 'Titanic',
#   'currentVersionNumberNullable': 1,
#   'usabilityRatingNullable': 0.7058824,
#   'id': 1275,
#   'ref': 'heptapod/titanic',
#   'subtitle': 'Suited for binary logistic regression',
#   'hasSubtitle': True,
#   'creatorName': 'Khashayar Baghizadeh Hosseini',
#   'hasCreatorName': True,
#   'creatorUrl': 'heptapod',
#   'hasCreatorUrl': True,
#   'totalBytes': 11090,
#   'hasTotalBytes': True,
#   'url': 'https://www.kaggle.com/datasets/heptapod/titanic',
#   'hasUrl': True,
# ...

# %%
api.dataset_download_files('heptapod/titanic', path=r'C:\Users\RodrigoPintoMesquita\.vscode\Meus Notebooks\Python\arquivos')

# %%
from zipfile import ZipFile
ZipFile(r'C:\Users\RodrigoPintoMesquita\.vscode\Meus Notebooks\Python\arquivos\titanic.zip').extractall(r'C:/Users/RodrigoPintoMesquita/.vscode/Meus Notebooks/Python/arquivos/titanic/')
ZipFile(r'C:\Users\RodrigoPintoMesquita\.vscode\Meus Notebooks\Python\arquivos\titanic.zip').close
# Out:
# <bound method ZipFile.close of <zipfile.ZipFile filename='C:\\Users\\RodrigoPintoMesquita\\.vscode\\Meus Notebooks\\Python\\arquivos\\titanic.zip' mode='r'>>
