# %%
{'dados': [{'id': 220593,
   'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/220593',
   'nome': 'Abilio Brunini',
   'siglaPartido': 'PL',
   'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/37906',
   'siglaUf': 'MT',
   'idLegislatura': 57,
   'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/220593.jpg',
   'email': 'dep.abiliobrunini@camara.leg.br'}

# %%
#Outra forma de contar a quantidade de registro por país

from collections import Counter

lista_paises = []
for linha in dados_organizados:
    lista_paises.append(linha["country"])

Counter(lista_paises)
# Out:
# Counter({'United States': 49, 'Ireland': 1})

# %%
import numpy as np
import matplotlib.pyplot as plt

# Dados de exemplo
categorias = ['Sabor A', 'Sabor B', 'Sabor C', 'Sabor D']
valores = [40, 25, 15, 30]

# Número de categorias
num_categorias = len(categorias)

# Ângulos para as categorias
angulos = np.linspace(0, 2 * np.pi, num_categorias, endpoint=False).tolist()
angulos += angulos[:1]  # Fecha o gráfico

# Valores para o primeiro e último ângulo para uma conexão fechada
valores += valores[:1]

# Crie um gráfico de radar
plt.figure(figsize=(8, 8))
ax = plt.subplot(111, polar=True)

# Ajuste as posições dos rótulos
ax.set_xticks(angulos[:-1])
ax.set_xticklabels(categorias)

# Plote os valores
ax.fill(angulos, valores, 'b', alpha=0.1)

# Adicione um título
plt.title("Gráfico de Radar")

# Mostrar o gráfico
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Dados de exemplo
categorias = ['Sabor A', 'Sabor B', 'Sabor C', 'Sabor D']
valores = [40, 25, 15, 30]

# Número de categorias
num_categorias = len(categorias)

# Ângulos para as categorias
angulos = np.linspace(0, 2 * np.pi, num_categorias, endpoint=False).tolist()
angulos += angulos[:1]  # Fecha o gráfico

# Valores para o primeiro e último ângulo para uma conexão fechada
valores += valores[:1]

# Crie um gráfico de radar
plt.figure(figsize=(8, 8))
ax = plt.subplot(111, polar=True)

# Ajuste as posições dos rótulos
offset = np.pi / 10  # Ajuste de offset para os rótulos
ax.set_xticks(angulos[:-1])
ax.set_xticklabels(categorias)

# Plote os valores
ax.fill(angulos, valores, 'b', alpha=0.1)

# Ajuste as posições dos rótulos para evitar sobreposição
for label, angle in zip(ax.get_xticklabels(), angulos[:-1]):
    x, y = label.get_position()
    if angle == np.pi / 2:
        x += 0.2  # Afastar rótulo da direção de 90 graus
    elif angle == 3 * np.pi / 2:
        x -= 0.2  # Afastar rótulo da direção de 270 graus
    label.set_position((x, y))

# Adicione um título
plt.title("Gráfico de Radar")

# Mostrar o gráfico
plt.show()
